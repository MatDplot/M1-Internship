# %% [markdown]
# # Setup

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import tensorflow_probability as tfp
import matplotlib.pyplot as plt
import random as rd
import os
from tqdm import tqdm
import tensorflow_addons as tfa
import pandas as pd
import matplotlib.gridspec as gridspec
from matplotlib.colorbar import Colorbar


plt.style.use(['science','ieee'])

os.chdir('/home/mathis/Stage M1/')
# Out:
# 2022-06-23 11:23:06.828817: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-06-23 11:23:06.828843: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %% [markdown]
# # Oracle

# %%
path = 'Advanced NN/NMFV/NMFV_plot/'
ext = 'higgs'
file = 'data_'

commande = 'mkdir -p Advanced\ NN/NMFV/NMFV_plot/'+ext+'_test/'
os.system(commande)

import csv
with open(path+file+ext+'.csv') as f:
    f.readline()
    data = csv.reader(f, delimiter='\t')
    data = list(data)

# %%
MW_mass = []
higgs_mass = [[] for i in range(4)]        #[h0 , H0 , A0 , H+]
g_mass = []
neutralino_mass = [[] for i in range(4)]   #[N1 , N2 , N3 , N4]
chargino_mass = [[] for i in range(2)]     #[neutralino1 , neutralino2]     
e_mass = [[] for i in range(6)]
nu_mass = [[] for i in range(3)]
d_mass = [[] for i in range(6)]
u_mass = [[] for i in range(6)]

sus_mass = [MW_mass,higgs_mass,g_mass,neutralino_mass,chargino_mass,e_mass,nu_mass,d_mass,u_mass]


tanB_param = []
M_param = [[] for i in range(3)]           #[M1 , M2 , M3
mu_param = []
mA_param = []

param = [tanB_param,M_param,mu_param,mA_param]


msq2_param = [[] for i in range(4)]
msu2_param = [[] for i in range(3)]
msd2_param = [[] for i in range(4)]
msl2_param = [[] for i in range(3)]
mse2_param = [[] for i in range(3)]

ms2_param = [msq2_param,msu2_param,msd2_param,msl2_param,mse2_param]


tu_param = [[] for i in range(9)]
td_param = [[] for i in range(9)]
te_param = []

t_param = [tu_param,td_param,te_param]

# %%
for k in tqdm(data):
    j = [float(i) for i in k]
            
        
    sus_mass[0].append(j[42])
    sus_mass[1][0].append(j[43])
    sus_mass[1][1].append(j[44])
    sus_mass[1][2].append(j[45])
    sus_mass[1][3].append(j[46])
    sus_mass[2].append(j[47])
    sus_mass[3][0].append(j[48])
    sus_mass[3][1].append(j[49])
    sus_mass[3][2].append(j[50])
    sus_mass[3][3].append(j[51])
    sus_mass[4][0].append(j[52])
    sus_mass[4][1].append(j[53])
    sus_mass[5][0].append(j[54])
    sus_mass[5][1].append(j[55])
    sus_mass[5][2].append(j[56])
    sus_mass[5][3].append(j[57])
    sus_mass[5][4].append(j[58])
    sus_mass[5][5].append(j[59])
    sus_mass[6][0].append(j[60])
    sus_mass[6][1].append(j[61])
    sus_mass[6][2].append(j[62])
    sus_mass[7][0].append(j[63])
    sus_mass[7][1].append(j[64])
    sus_mass[7][2].append(j[65])
    sus_mass[7][3].append(j[66])
    sus_mass[7][4].append(j[67])
    sus_mass[7][5].append(j[68])
    sus_mass[8][0].append(j[69])
    sus_mass[8][1].append(j[70])
    sus_mass[8][2].append(j[71])
    sus_mass[8][3].append(j[72])
    sus_mass[8][4].append(j[73])
    sus_mass[8][5].append(j[74])
        
    param[0].append(j[0])
    param[1][0].append(j[1])
    param[1][1].append(j[2])
    param[1][2].append(j[3])
    param[2].append(j[4])
    param[3].append(j[5])
    
    ms2_param[0][0].append(j[6])
    ms2_param[0][1].append(j[7])
    ms2_param[0][2].append(j[8])
    ms2_param[0][3].append(j[9])
    ms2_param[1][0].append(j[10])
    ms2_param[1][1].append(j[11])
    ms2_param[1][2].append(j[12])
    ms2_param[2][0].append(j[13])
    ms2_param[2][1].append(j[14])
    ms2_param[2][2].append(j[15])
    ms2_param[2][3].append(j[16])
    ms2_param[3][0].append(j[17])
    ms2_param[3][1].append(j[18])
    ms2_param[3][2].append(j[19])
    ms2_param[4][0].append(j[20])
    ms2_param[4][1].append(j[21])
    ms2_param[4][2].append(j[22])
    
    t_param[0][0].append(j[23])
    t_param[0][1].append(j[24])
    t_param[0][2].append(j[25])
    t_param[0][3].append(j[26])
    t_param[0][4].append(j[27])
    t_param[0][5].append(j[28])
    t_param[0][6].append(j[29])
    t_param[0][7].append(j[30])
    t_param[0][8].append(j[31])
    t_param[1][0].append(j[32])
    t_param[1][1].append(j[33])
    t_param[1][2].append(j[34])
    t_param[1][3].append(j[35])
    t_param[1][4].append(j[36])
    t_param[1][5].append(j[37])
    t_param[1][6].append(j[38])
    t_param[1][7].append(j[39])
    t_param[1][8].append(j[40])
    t_param[2].append(j[41])
# Out:
# 100%|██████████████████████████████████████| 590/590 [00:00<00:00, 33038.36it/s]

# %%
def plot_histo(title, xlabel, ylabel, list_hist,bins, label, color='blue', legend = False, histtype='bar', save=False, file_folder=''):
    plt.figure()
    for indice, hist in enumerate(list_hist):
        plt.hist(hist,bins,label=label[indice],histtype=histtype,color=color[indice],stacked=True,linestyle='solid')
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    if legend == True:
        plt.legend()
    if save == True:
        plt.savefig(file_folder)
    
def subplot_histo(titre, xlabel, ylabel, bins, x, y, share, subtitle, hist_list, label, color='blue', legend = False, histtype='bar', save=False, file_folder=''):  
    fig , ax = plt.subplots(x, y, sharex=share[0], sharey=share[1], constrained_layout = True)
    plt.suptitle(titre)
    fig.text(0.5, -0.05, xlabel, ha='center')
    fig.text(-0.04, 0.5, ylabel, va='center', rotation='vertical')

    for indice, hist in enumerate(hist_list): 
        compteur = 0
        for i in range(x):
            if y != 1:
                for j in range(y):
                    ax[i, j].hist(hist[compteur],bins,histtype=histtype,label=label[indice], color=color[indice], stacked=True, linestyle='solid')
                    ax[i, j].set_title(subtitle[compteur])
                    compteur+=1
                    if legend == True:
                        ax[i, j].legend()
            else:
                ax[i].hist(hist[compteur],bins,histtype=histtype, label=label[indice], color=color[indice], stacked=True, linestyle='solid')
                ax[i].set_title(subtitle[compteur])
                compteur+=1
                if legend == True:
                    ax[i].legend()
    if save == True:
        plt.savefig(file_folder)

# %%
folder = 'Advanced NN/NMFV/NMFV_plot/'+ext+'_test'

file = '/histo_W.pdf'
titre = r'Histogramme de la masse du W'
xlabel = 'Masse (GeV)'
ylabel = 'N'
bins = 50
plot_histo(titre,xlabel,ylabel,[MW_mass],bins,['NN'],save=True,file_folder=folder+file)

file = '/histo_g.pdf'
titre = r'Histogramme de la masse du gluino $\widetilde{g}$'
plot_histo(titre,xlabel,ylabel,[g_mass],bins,['NN'],save=True,file_folder=folder+file)

file = '/histo_neutralinos.pdf'
titre = 'Histogramme de la masse des neutralinos'
subtitle = [r'$\widetilde{\chi_1^0}$',r'$\widetilde{\chi_2^0}$',r'$\widetilde{\chi_3^0}$',r'$\widetilde{\chi_4^0}$']
share = [False,True]
subplot_histo(titre,xlabel,ylabel,bins,2,2,share,subtitle,[neutralino_mass],['NN'],save=True,file_folder=folder+file)

file = '/histo_higgs.pdf'
titre = 'Histogramme de la masse des bosons de Higgs'    
subtitle = [r'$h_0$',r'$H_0$',r'$A_0$',r'$H^+$']
subplot_histo(titre,xlabel,ylabel,bins,2,2,share,subtitle,[higgs_mass],['NN'],save=True,file_folder=folder+file)

file = '/histo_charginos.pdf'
titre = 'Histogramme de la masse des charginos'    
subtitle = [r'$\widetilde{\chi_1^\pm}$',r'$\widetilde{\chi_2^\pm}$']
subplot_histo(titre,xlabel,ylabel,bins,2,1,share,subtitle,[chargino_mass],['NN'],save=True,file_folder=folder+file)

file = '/histo_e.pdf'
titre = 'Histogramme des élements de la matrice e'    
subtitle = ['e1','e2','e3','e4','e5','e6']
subplot_histo(titre,xlabel,ylabel,bins,2,3,share,subtitle,[e_mass],['NN'],save=True,file_folder=folder+file)

file = '/histo_d.pdf'
titre = 'Histogramme des élements de la matrice d'    
subtitle = ['d1','d2','d3','d4','d5','d6']
subplot_histo(titre,xlabel,ylabel,bins,2,3,share,subtitle,[d_mass],['NN'],save=True,file_folder=folder+file)

file = '/histo_e.pdf'
titre = 'Histogramme des élements de la matrice u'    
subtitle = ['u1','u2','u3','u4','u5','u6']
subplot_histo(titre,xlabel,ylabel,bins,2,3,share,subtitle,[u_mass],['NN'],save=True,file_folder=folder+file)

file = '/histo_nu.pdf'
titre = r'Histogramme des $\nu$'    
subtitle = [r'$\nu_1$',r'$\nu_2$',r'$\nu_3$']
subplot_histo(titre,xlabel,ylabel,bins,3,1,share,subtitle,[nu_mass],['NN'],save=True,file_folder=folder+file)

# %%
file = '/histo_mu.pdf'
titre = r'Histogramme du paramètre $\mu$'
plot_histo(titre,xlabel,ylabel,[mu_param],bins,['NN'],save=True,file_folder=folder+file)

file = '/histo_M.pdf'
titre = 'Histogramme des paramètres de masse'
subtitle = [r'$M_1$',r'$M_2$',r'$M_3$']
subplot_histo(titre,xlabel,ylabel,bins,3,1,share,subtitle,[M_param],['NN'],save=True,file_folder=folder+file)

file = '/histo_mA.pdf'
titre = r'Histogramme du paramètre $M_A$'
plot_histo(titre,xlabel,ylabel,[mA_param],bins,['NN'],save=True,file_folder=folder+file)

file = '/histo_tanb.pdf'
titre = r'Histogramme du paramètre $\tan \beta$'
plot_histo(titre,xlabel,ylabel,[tanB_param],bins,['NN'],save=True,file_folder=folder+file)

# %%
file = '/histo_msq2.pdf'
titre = r'Histogramme des éléments de matrice $m^2_Q$'
subtitle = ['11','22','23','33']
subplot_histo(titre,xlabel,ylabel,bins,2,2,share,subtitle,[msq2_param],['NN'],save=True,file_folder=folder+file)

file = '/histo_msd2.pdf'
titre = r'Histogramme des éléments de matrice $m^2_d$'
subtitle = ['11','22','23','33']
subplot_histo(titre,xlabel,ylabel,bins,2,2,share,subtitle,[msd2_param],['NN'],save=True,file_folder=folder+file)

file = '/histo_msu2.pdf'
titre = r'Histogramme des éléments de matrice $m^2_u$'
subtitle = ['11','22','33']
subplot_histo(titre,xlabel,ylabel,bins,3,1,share,subtitle,[msu2_param],['NN'],save=True,file_folder=folder+file)

file = '/histo_msl2.pdf'
titre = r'Histogramme des éléments de matrice $m^2_L$'
subtitle = ['11','22','33']
subplot_histo(titre,xlabel,ylabel,bins,3,1,share,subtitle,[msl2_param],['NN'],save=True,file_folder=folder+file)

file = '/histo_mse2.pdf'
titre = r'Histogramme des éléments de matrice $m^2_e$'
subtitle = ['11','22','33']
subplot_histo(titre,xlabel,ylabel,bins,3,1,share,subtitle,[mse2_param],['NN'],save=True,file_folder=folder+file)

# %%
file = '/histo_tu.pdf'
titre = r'Histogramme des éléments de matrice $T_u$'
subtitle = ['11','12','13','21','22','23','31','32','33']
subplot_histo(titre,xlabel,ylabel,bins,3,3,share,subtitle,[tu_param],['NN'],save=True,file_folder=folder+file)

file = '/histo_td.pdf'
titre = r'Histogramme des éléments de matrice $T_d$'
subtitle = ['11','12','13','21','22','23','31','32','33']
subplot_histo(titre,xlabel,ylabel,bins,3,3,share,subtitle,[td_param],['NN'],save=True,file_folder=folder+file)

file = '/histo_te.svg'
titre = r'Histogramme de $T_{e33}$'
plot_histo(titre,xlabel,ylabel,[te_param],bins,['NN'],save=True,file_folder=folder+file)

# %%
import matplotlib.gridspec as gridspec
from matplotlib.colorbar import Colorbar
import matplotlib
from matplotlib.colors import LogNorm

fig = plt.figure(1, figsize=(15,8))
gs = gridspec.GridSpec(3,4, height_ratios=[0.2,1,0.05], width_ratios=[1,0.2,0.2,1])
gs.update(left=0.05, right=0.95, bottom=0.08, top=0.93, wspace=0.1, hspace=0.15)


ax1 = plt.subplot(gs[1,0])
h = ax1.hist2d(M_param[0], M_param[1], bins=50, cmap=plt.cm.jet)

x_min = min(M_param[0])
x_max = max(M_param[0])
y_min = min(M_param[1])
y_max = max(M_param[1])

ax1.grid(False)
ax1.set_xlim([x_min,x_max])
ax1.set_ylim([y_min,y_max])
#ax1.set_xlabel(r' ') 
#ax1.set_xticks(np.linspace(0,1,9)) 
#ax1.set_xticklabels([]) 
ax1.set_ylabel(r'Active Learning')

cbax = plt.subplot(gs[2,0]) 

cb = Colorbar(ax = cbax, mappable = h[3], orientation = 'horizontal', ticklocation = 'bottom')
cb.set_label(r'Density', labelpad=10)




ax1v = plt.subplot(gs[1,1])


bins = np.arange(0,1,0.01)
ax1v.hist(M_param[1],bins=10, orientation='horizontal', color='b', edgecolor='w')


#ax1v.set_yticks(np.linspace(0,1,9)) 
#ax1v.set_xticklabels([])
ax1v.set_yticklabels([])
ax1v.set_ylim([y_min,y_max])
ax1v.set_xlabel(r'$M_2$')
ax1v.grid(True)


ax1h = plt.subplot(gs[0,0])


bins = np.arange(0,1,0.01)
ax1h.hist(M_param[0], bins=10, orientation='vertical', color='b', edgecolor='w')

#ax1h.set_xticks(np.linspace(0,1,9))
ax1h.set_xticklabels([])
#ax1h.set_yticklabels([])
ax1h.set_xlim([x_min,x_max])
ax1h.set_ylabel(r'$M_1$')
ax1h.grid(True)

plt.savefig(folder+'/density_M1M2.pdf')

# %%
fig = plt.figure(1, figsize=(15,8))
gs = gridspec.GridSpec(3,4, height_ratios=[0.2,1,0.05], width_ratios=[1,0.2,0.2,1])
gs.update(left=0.05, right=0.95, bottom=0.08, top=0.93, wspace=0.1, hspace=0.15)


ax1 = plt.subplot(gs[1,0])
h = ax1.hist2d(u_mass[0], u_mass[5], bins=50, norm=LogNorm(), cmap=plt.cm.jet)

x_min = min(u_mass[0])
x_max = max(u_mass[0])
y_min = min(u_mass[5])
y_max = max(u_mass[5])

ax1.grid(False)
ax1.set_xlim([x_min,x_max])
ax1.set_ylim([y_min,y_max])
#ax1.set_xlabel(r' ') 
#ax1.set_xticks(np.linspace(0,1,9)) 
#ax1.set_xticklabels([]) 
ax1.set_ylabel(r'Active Learning')

cbax = plt.subplot(gs[2,0]) 

cb = Colorbar(ax = cbax, mappable = h[3], orientation = 'horizontal', ticklocation = 'bottom')
cb.set_label(r'Density', labelpad=10)




ax1v = plt.subplot(gs[1,1])


bins = np.arange(0,1,0.01)
ax1v.hist(u_mass[5],bins=50, orientation='horizontal', color='b', edgecolor='w')


#ax1v.set_yticks(np.linspace(0,1,9)) 
#ax1v.set_xticklabels([])
ax1v.set_yticklabels([])
ax1v.set_ylim([y_min,y_max])
ax1v.set_xlabel(r'$u_6$')
ax1v.grid(True)


ax1h = plt.subplot(gs[0,0])


bins = np.arange(0,1,0.01)
ax1h.hist(u_mass[0], bins=50, orientation='vertical', color='b', edgecolor='w')

#ax1h.set_xticks(np.linspace(0,1,9))
ax1h.set_xticklabels([])
#ax1h.set_yticklabels([])
ax1h.set_xlim([x_min,x_max])
ax1h.set_ylabel(r'$u_1$')
ax1h.grid(True)

plt.savefig(folder+'/density_u1u6.pdf')

# %%
fig = plt.figure(1, figsize=(15,8))
gs = gridspec.GridSpec(3,4, height_ratios=[0.2,1,0.05], width_ratios=[1,0.2,0.2,1])
gs.update(left=0.05, right=0.95, bottom=0.08, top=0.93, wspace=0.1, hspace=0.15)


ax1 = plt.subplot(gs[1,0])
h = ax1.hist2d(tanB_param, mu_param, bins=50, cmap=plt.cm.jet)

x_min = min(tanB_param)
x_max = max(tanB_param)
y_min = min(mu_param)
y_max = max(mu_param)

ax1.grid(False)
ax1.set_xlim([x_min,x_max])
ax1.set_ylim([y_min,y_max])
#ax1.set_xlabel(r' ') 
#ax1.set_xticks(np.linspace(0,1,9)) 
#ax1.set_xticklabels([]) 
ax1.set_ylabel(r'Active Learning')

cbax = plt.subplot(gs[2,0]) 

cb = Colorbar(ax = cbax, mappable = h[3], orientation = 'horizontal', ticklocation = 'bottom')
cb.set_label(r'Density', labelpad=10)




ax1v = plt.subplot(gs[1,1])


bins = np.arange(0,1,0.01)
ax1v.hist(mu_param,bins=10, orientation='horizontal', color='b', edgecolor='w')


#ax1v.set_yticks(np.linspace(0,1,9)) 
#ax1v.set_xticklabels([])
ax1v.set_yticklabels([])
ax1v.set_ylim([y_min,y_max])
ax1v.set_xlabel(r'$\mu$')
ax1v.grid(True)


ax1h = plt.subplot(gs[0,0])


bins = np.arange(0,1,0.01)
ax1h.hist(tanB_param, bins=10, orientation='vertical', color='b', edgecolor='w')

#ax1h.set_xticks(np.linspace(0,1,9))
ax1h.set_xticklabels([])
#ax1h.set_yticklabels([])
ax1h.set_xlim([x_min,x_max])
ax1h.set_ylabel(r'$\tan \beta$')
ax1h.grid(True)

plt.savefig(folder+'/density_tanmu.pdf')

# %%
fig = plt.figure(1, figsize=(15,8))
gs = gridspec.GridSpec(3,4, height_ratios=[0.2,1,0.05], width_ratios=[1,0.2,0.2,1])
gs.update(left=0.05, right=0.95, bottom=0.08, top=0.93, wspace=0.1, hspace=0.15)


ax1 = plt.subplot(gs[1,0])
h = ax1.hist2d(neutralino_mass[0], chargino_mass[0], bins=50, norm=LogNorm(), cmap=plt.cm.jet)

x_min = 0
x_max = max(neutralino_mass[0])
y_min = min(chargino_mass[0])
y_max = max(chargino_mass[0])

ax1.grid(False)
ax1.set_xlim([x_min,x_max])
ax1.set_ylim([y_min,y_max])
#ax1.set_xlabel(r' ') 
#ax1.set_xticks(np.linspace(0,1,9)) 
#ax1.set_xticklabels([]) 
ax1.set_ylabel(r'Active Learning')

cbax = plt.subplot(gs[2,0]) 

cb = Colorbar(ax = cbax, mappable = h[3], orientation = 'horizontal', ticklocation = 'bottom')
cb.set_label(r'Density', labelpad=10)


ax1.plot([0,10000],[0,10000],'-',color='black', label='y=x')
ax1.legend(loc='upper center', bbox_to_anchor=(0.5, -0.2),
          fancybox=True, shadow=True, ncol=5)

ax1v = plt.subplot(gs[1,1])


bins = np.arange(0,1,0.01)
ax1v.hist(chargino_mass[0],bins=50, orientation='horizontal', color='b', edgecolor='w')


#ax1v.set_yticks(np.linspace(0,1,9)) 
#ax1v.set_xticklabels([])
ax1v.set_yticklabels([])
ax1v.set_ylim([y_min,y_max])
ax1v.set_xlabel(r'$\widetilde{\chi_1^\pm}$')
ax1v.grid(True)


ax1h = plt.subplot(gs[0,0])


bins = np.arange(0,1,0.01)
ax1h.hist(neutralino_mass[0], bins=50, orientation='vertical', color='b', edgecolor='w')

#ax1h.set_xticks(np.linspace(0,1,9))
ax1h.set_xticklabels([])
#ax1h.set_yticklabels([])
ax1h.set_xlim([x_min,x_max])
ax1h.set_ylabel(r'$\widetilde{\chi_1^0}$')
ax1h.grid(True)

plt.savefig(folder+'/density_chi.pdf')

# %%
# create dataframe from file
dataframe = pd.read_csv('Advanced NN/NMFV/NMFV_plot/data_'+ext+'.csv', header=0, sep='\t')
 
# show dataframe
print(dataframe)
# use corr() method on dataframe to
# make correlation matrix
matrix = dataframe.corr()
 
# print correlation matrix
print("Correlation Matrix is : ")
#print(matrix)

#plt.matshow(matrix)
#plt.show()
# Out:
#           tanb           M1           M2          M3           mu  \
# 0     4.443816   131.997599  4555.878990  4182.04186  1970.420950
# 1     4.900945  3895.374600  1605.082150  2178.78479 -1016.101800
# 2    14.502024   782.017980   876.107761  3755.16608  7285.649800
# 3    24.384000  1749.615030  3961.022450  2058.28905   210.415364
# 4    20.516431  4567.285140   294.991007  3853.63709 -1918.295670
# ..         ...          ...          ...         ...          ...
# 585   6.181573   284.823537  1036.398500  2221.39353 -7866.146710
# 586  25.748573   471.942310  4935.172860  4828.23482 -4898.511770
# 587  36.750845  1152.109270  3176.686830  2911.22455  -854.374170
# 588  20.621314   277.188562  3379.016100  3993.55466   853.418112
# 589  31.416549  4944.184650   770.729397  3546.85957  6663.389210
#
#               mA      msq2_11     msq2_22     msq2_23     msq2_33  ...  \
# 0    3610.879080  1275160.130  2643037.84  611.585347  3847249.78  ...
# ...

# %%
import seaborn as sns

f, ax = plt.subplots(figsize=(10, 8))
corr = dataframe.corr()
sns.heatmap(corr, mask=np.zeros_like(corr, dtype=np.bool), cmap=sns.diverging_palette(220, 10, as_cmap=True),
            square=True, ax=ax)

plt.savefig(folder+'/correlation_matrix.pdf')
# Out:
# /tmp/ipykernel_14321/889543274.py:5: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   sns.heatmap(corr, mask=np.zeros_like(corr, dtype=np.bool), cmap=sns.diverging_palette(220, 10, as_cmap=True),

# %%
corr = dataframe.corr()
fig = plt.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(corr,cmap='coolwarm', vmin=-1, vmax=1)
fig.colorbar(cax)
ticks = np.arange(0,len(dataframe.columns),1)
ax.set_xticks(ticks)
plt.xticks(rotation=90)
ax.set_yticks(ticks)
ax.set_xticklabels(dataframe.columns)
ax.set_yticklabels(dataframe.columns)
plt.savefig(folder+'/correlation_matrix_all.pdf')

# %%
up_pd = dataframe[['tu_11','tu_12','tu_13','tu_22','tu_23','tu_31','tu_32','tu_33',
                     'msu2_11','msu2_22','msu2_33','u1','u2','u3','u4','u5','u6']]

corr = up_pd.corr()
fig = plt.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(corr,cmap='coolwarm', vmin=-1, vmax=1)
fig.colorbar(cax)
ticks = np.arange(0,len(up_pd.columns),1)
ax.set_xticks(ticks)
plt.xticks(rotation=90)
ax.set_yticks(ticks)
ax.set_xticklabels(up_pd.columns)
ax.set_yticklabels(up_pd.columns)
plt.savefig(folder+'/correlation_matrix_up.pdf')

# %%
dw_pd = dataframe[['td_11','td_12','td_13','td_22','td_23','td_31','td_32','td_33',
                    'msd2_11','msd2_22','msd2_23','msd2_33','d1','d2','d3','d4','d5','d6']]

corr = dw_pd.corr()
fig = plt.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(corr,cmap='coolwarm', vmin=-1, vmax=1)
fig.colorbar(cax)
ticks = np.arange(0,len(dw_pd.columns),1)
ax.set_xticks(ticks)
plt.xticks(rotation=90)
ax.set_yticks(ticks)
ax.set_xticklabels(dw_pd.columns)
ax.set_yticklabels(dw_pd.columns)
plt.savefig(folder+'/correlation_matrix_dw.pdf')

# %%
e_pd = dataframe[['te_33','mse2_11','mse2_22','mse2_33','e1','e2','e3','e4','e5','e6']]

corr = e_pd.corr()
fig = plt.figure()
ax = fig.add_subplot(111)
cax = ax.matshow(corr,cmap='coolwarm', vmin=-1, vmax=1)
fig.colorbar(cax)
ticks = np.arange(0,len(e_pd.columns),1)
ax.set_xticks(ticks)
plt.xticks(rotation=90)
ax.set_yticks(ticks)
ax.set_xticklabels(e_pd.columns)
ax.set_yticklabels(e_pd.columns)
plt.savefig(folder+'/correlation_matrix_e.pdf')

# %%
f, ax = plt.subplots(figsize=(10, 8))
corr = e_pd.corr()
sns.heatmap(corr, mask=np.zeros_like(corr, dtype=np.bool), cmap=sns.color_palette("coolwarm", as_cmap=True),
            square=True, ax=ax, annot=True)
# Out:
# /tmp/ipykernel_14321/376162784.py:3: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   sns.heatmap(corr, mask=np.zeros_like(corr, dtype=np.bool), cmap=sns.color_palette("coolwarm", as_cmap=True),
# <AxesSubplot:>

# %%
delta_u_23_LR = []
delta_d_23_LL = []

for i in range(len(tanB_param)):
    delta_d_23_LL.append(msq2_param[2][i]/np.sqrt((msq2_param[1][i]*msq2_param[3][i])))
    
    v_u = np.sin(np.arctan(tanB_param[i]))
    
    delta_u_23_LR.append((v_u/np.sqrt(2))*tu_param[7][i]/np.sqrt((msq2_param[3][i]*msu2_param[1][i])))

# %%
plt.plot(delta_u_23_LR,delta_d_23_LL,'ob')
plt.xlabel(r'$(\delta^u_{23})_{LR}$')
plt.ylabel(r'$(\delta^d_{23})_{LL}$')
# Out:
# Text(0, 0.5, '$(\\delta^d_{23})_{LL}$')

# %%
fig = plt.figure(1, figsize=(15,8))
gs = gridspec.GridSpec(3,4, height_ratios=[0.2,1,0.05], width_ratios=[1,0.2,0.2,1])
gs.update(left=0.05, right=0.95, bottom=0.08, top=0.93, wspace=0.1, hspace=0.15)


ax1 = plt.subplot(gs[1,0])
h = ax1.hist2d(delta_u_23_LR, delta_d_23_LL, bins=50, norm=LogNorm(), cmap=plt.cm.jet)

x_min = min(delta_u_23_LR)
x_max = max(delta_u_23_LR)
y_min = min(delta_d_23_LL)
y_max = max(delta_d_23_LL)

ax1.grid(False)
ax1.set_xlim([x_min,x_max])
ax1.set_ylim([y_min,y_max])
#ax1.set_xlabel(r' ') 
#ax1.set_xticks(np.linspace(0,1,9)) 
#ax1.set_xticklabels([]) 
ax1.set_ylabel(r'Active Learning')

cbax = plt.subplot(gs[2,0]) 

cb = Colorbar(ax = cbax, mappable = h[3], orientation = 'horizontal', ticklocation = 'bottom')
cb.set_label(r'Density', labelpad=10)


ax1v = plt.subplot(gs[1,1])


bins = np.arange(0,1,0.01)
ax1v.hist(delta_d_23_LL,bins=50, orientation='horizontal', color='b', edgecolor='w')


#ax1v.set_yticks(np.linspace(0,1,9)) 
#ax1v.set_xticklabels([])
ax1v.set_yticklabels([])
ax1v.set_ylim([y_min,y_max])
ax1v.set_xlabel(r'$(\delta^d_{23})_{LL}$')
ax1v.grid(True)


ax1h = plt.subplot(gs[0,0])


bins = np.arange(0,1,0.01)
ax1h.hist(delta_u_23_LR, bins=50, orientation='vertical', color='b', edgecolor='w')

#ax1h.set_xticks(np.linspace(0,1,9))
ax1h.set_xticklabels([])
#ax1h.set_yticklabels([])
ax1h.set_xlim([x_min,x_max])
ax1h.set_ylabel(r'$(\delta^u_{23})_{LR}$')
ax1h.grid(True)


plt.savefig(folder+'/delta.pdf')
